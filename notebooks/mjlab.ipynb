# %% [markdown]
# <a href="https://colab.research.google.com/github/ttktjmt/mjlab/blob/main/notebooks/mjlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🤖 Mjlab Tutorial**

# %% [markdown]
# ## **⚙️ Setting up the environment**
#
# Add secrets:
#
# *   `WANDB_API_KEY`: from [wandb.ai/authorize](https://wandb.ai/authorize)
# *   `WANDB_ORG`: your wandb organization name

# %%
# install uv (only if not installed)
# !if ! command -v uv &> /dev/null; then curl -LsSf https://astral.sh/uv/install.sh | sh -s -- -q; fi

# clone the git repository only if not exists
# !if [ ! -d "mjlab" ]; then git clone -q https://github.com/mujocolab/mjlab.git; fi
# %cd /content/mjlab

# set up venv
# !uv sync -q

# disable wandb
import os
from google.colab import userdata
os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')
os.environ['WANDB_ENTITY'] = userdata.get('WANDB_ENTITY')
# Out:
# /content/mjlab

# %%
import subprocess
import sys

process = subprocess.Popen(
  [
    "uv",
    "run",
    "demo",
  ],
  stdout=subprocess.PIPE,
  stderr=subprocess.STDOUT,
  universal_newlines=True,
  bufsize=1,
)

for line in process.stdout:
  print(line, end="")
  sys.stdout.flush()

  if "serving" in line.lower() or "running on" in line.lower() or "8081" in line:
    print("\n" + "=" * 52)
    print("✅ Server is running! Execute the next cell to view.")
    print("=" * 52)
    break
# Out:
# 🎮 Setting up MJLab demo with pretrained tracking policy...
# 📥 Downloading demo_ckpt.pt...
#
# demo_ckpt.pt:   0%|          | 0.00/6.46M [00:00<?, ?B/s]
# demo_ckpt.pt:  71%|███████   | 4.57M/6.46M [00:00<00:00, 47.9MB/s]
# demo_ckpt.pt: 100%|██████████| 6.46M/6.46M [00:00<00:00, 60.1MB/s]
# ✅ demo_ckpt.pt cached at /tmp/mjlab_cache/demo_ckpt.pt
# 📥 Downloading demo_motion.npz...
#
# lafan1_dance1_subject1_demo_motion.npz:   0%|          | 0.00/11.2M [00:00<?, ?B/s]
# lafan1_dance1_subject1_demo_motion.npz:  64%|██████▍   | 7.23M/11.2M [00:00<00:00, 75.8MB/s]
# lafan1_dance1_subject1_demo_motion.npz: 100%|██████████| 11.2M/11.2M [00:00<00:00, 90.1MB/s]
# Warp CUDA warning: Could not find or load the NVIDIA CUDA driver. Proceeding in CPU-only mode.

# %%
from google.colab import output

output.serve_kernel_port_as_iframe(
    port=8081,
    width='100%',
    height=700,
)
